# %%
# Install the scrapy
# !pip install scrapy
# Start web scraping project with scrapys
# !scrapy startproject TRTWorld
# !cd TRTWorld
# !scrapy genspider Articles trtworld.com
# !scrapy genspider ArticleScraper trtworld.com
# Out:
# ...
# Error: Module 'TRTWorld' already exists
# Created spider 'Articles' using template 'basic' in module:
#   TRTWorld.spiders.Articles
# Created spider 'ArticleScraper' using template 'basic' in module:
#   TRTWorld.spiders.ArticleScraper

# %%
# !ls
# Out:
# scrapy.cfg  TRTWorld

# %%
cd TRTWorld
# Out:
# /content/TRTWorld/TRTWorld

# %%
cd /..

# %%
ls
# Out:
# run.sh*  web/

# %%
scrapy crawl -o article_links.json -t json Articles
