# %% [markdown]
# #    Import Libraries and Upload Files

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

import matplotlib.pyplot as pyplot
import pickle
from matplotlib import style

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1b98a97f-af05-4aab-b889-801e85cddb58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b98a97f-af05-4aab-b889-801e85cddb58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
data = pd.read_csv("student-mat.csv",sep=";")

# %%
data = data[["G1","G2", "G3","studytime","failures","absences"]]
np.array
predict = "G3" #we're going to predict G3, the final grade

x = np.array(data.drop([predict],1))
y = np.array(data[predict])

# %%
print(acc)
# Out:
# 0.7826315702693081

# %%
print("Coefficient: \n", linear.coef_)
print("Intercepts: \n", linear.intercept_)
# Out:
# Coefficient:
#  [ 0.17330362  0.96350167 -0.12633204 -0.22870034  0.03797293]
# Intercepts:
#  -1.706916869440608

# %% [markdown]
# # Saving Models & Plotting Data

# %%
best = 0
for i in range(30):
  x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)
  linear = linear_model.LinearRegression()
  linear.fit(x_train, y_train)
  acc = linear.score(x_test,y_test)
  if acc > best:
    with open("studentmodel.pickle", "wb") as f:
      pickle.dump(linear, f)

# %%
p = "G1"
style.use("ggplot")
pyplot.scatter(data[[p]],data[["G3"]])
pyplot.xlabel(p)
pyplot.ylabel("Final Grade")
pyplot.show()
