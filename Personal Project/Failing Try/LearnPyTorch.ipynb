# %%
import torch

# %%
x=torch.Tensor(2)

# %%
torch.randn(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-943bcf7b84ed> in <module>()
# ----> 1 torch.randn(2)
#
# NameError: name 'torch' is not defined
