# %%
# clone project
! git clone https://github.com/pyliaorachel/pytorch-mnist-interactive.git
! cd MNIST-pytorch-tensorflow-eager-interactive

# install dependencies


# train & test model
! python3 -m pytorch.train
# ...data will be fetched to ../data/
# ...trained model will be saved to ./pytorch/model
# or
! python3 -m tensorflow_eager.train
# ...data will be fetched to somewhere
# ...trained model will be saved to ./tensorflow_eager/checkpoint & ./tensorflow_eager/ckpt-*

# test model interactively
! python3 -m pytorch.app --image=<path-to-image>
# or
! python3 -m tensorflow_eager.app --image=<path-to-image>
# Out:
# fatal: destination path 'pytorch-mnist-interactive' already exists and is not an empty directory.
# /bin/bash: line 0: cd: MNIST-pytorch-tensorflow-eager-interactive: No such file or directory
# /usr/bin/python3: Error while finding module specification for 'pytorch.train' (ModuleNotFoundError: No module named 'pytorch')
# /usr/bin/python3: Error while finding module specification for 'tensorflow_eager.train' (ModuleNotFoundError: No module named 'tensorflow_eager')
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` python3 -m pytorch.app --image=<path-to-image>'
# /bin/bash: -c: line 0: syntax error near unexpected token `newline'
# /bin/bash: -c: line 0: ` python3 -m tensorflow_eager.app --image=<path-to-image>'
