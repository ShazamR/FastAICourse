# %%
# !pip3 install transformers
# Out:
# ...
#      |████████████████████████████████| 1.3MB 13.8MB/s
# ...
#      |████████████████████████████████| 2.9MB 41.0MB/s
# ...
#      |████████████████████████████████| 890kB 42.3MB/s
# ...
#      |████████████████████████████████| 1.1MB 52.8MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=7c38c833fe9b11ce623ff6f83fa013dfe21a0dccf3bf5e7ede6cc9558eff905b
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
import numpy as np
import pandas as pd
import torch
from transformers import BertTokenizer

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Hello Google Drive!

# %%
model = torch.load('/gdrive/MyDrive/10th grade/2020 Personal Project/model savepoint/model_after_train.pt')

# %%
df_path = '/gdrive/MyDrive/10th grade/2020 Personal Project/Dataset/politifact_phase2_clean_2018_7_3.csv'
df = pd.read_csv(df_path, header=None, sep='\n')
df = df[0].str.split(',', expand=True)

# %%
df.head()
# Out:
#                                                 0     ...  3885
# 0                              politifact_url_phase1  ...  None
# 1  http://www.politifact.com/punditfact/statement...  ...  None
# 2  http://www.politifact.com/punditfact/statement...  ...  None
# 3  http://www.politifact.com/punditfact/statement...  ...  None
# 4  http://www.politifact.com/illinois/statements/...  ...  None
#
# [5 rows x 3886 columns]

# %%
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_dataset, test_dataset = torch.utils.data.random_split(df, [train_size, test_size])
trainLoader = torch.utils.data.DataLoader(dataset = train_dataset)

# %%
print(train)

# %%
print(train_dataset)
